# %%
# %fs
ls dbfs:/

# %%
# %fs
ls 'dbfs:/databricks-datasets/'

# %%
# %fs
ls '/Volumes/workspace/default/arquivos-aula/arquivos_csv'

# %%
file_path='dbfs:/Volumes/workspace/default/arquivos-aula/arquivos_csv/Clientes.csv'
df_clientes = spark.read.format('csv') \
    .option('header','true') \
    .option('inferSchema','true') \
    .option('delimiter',',') \
    .load(file_path)
display(df_clientes)

# %%
file_path='dbfs:/Volumes/workspace/default/arquivos-aula/arquivos_csv/Clientes.csv'
df_clientes = spark.read.format('csv') \
    .option('header','true') \
    .option('inferSchema','true') \
    .option('delimiter',',') \
    .load(file_path)

df_clientes.write.mode('overwrite').saveAsTable('clientes')

# %%
# %sql
select * From default.clientes

# %%
display(dbutils.fs.ls("/"))

# %%
def caminho_existe(path):
    try:
        return len(dbutils.fs.ls(path)) >= 0
    except:
        return False

if caminho_existe("/mnt/datalake/clientes"):
    print("Existe")
else:
    print("Não existe")

# %%
if not caminho_existe("/Volumes/workspace/default/main/clientes"):
    dbutils.fs.mkdirs("/Volumes/workspace/default/main/clientes")

# %%
# %sql
DROP TABLE workspace.bronze.bronze_clientes;
DROP TABLE workspace.silver.silver_clientes;
DROP TABLE workspace.gold.gold_clientes;

# %%
# %sql
SHOW VOLUMES IN workspace.default;
